# %%
using System;
using System.Collections.Generic;


public interface IEnterprise
{
    void AddSupplier(ISupplier supplier);
    void AddEmployee(IEmployee employee);
    List<ISupplier> GetSuppliers();
    List<IEmployee> GetEmployees();
}
public interface ISupplier
{
    string GetName();
    decimal GetCost();
    string SupplierType{get;set;}
}
public interface IEmployee
{
    string GetFullName();
    decimal GetSalary();
    string Position{get;set;}

}
public class Enterprise: IEnterprise
{
    List<ISupplier> suppliers = new List<ISupplier>();
    List<IEmployee> employees = new List<IEmployee>();
    public void AddSupplier(ISupplier supplier)
    {
        suppliers.Add(supplier);
    }
    public void AddEmployee(IEmployee employee)
    {
        employees.Add(employee);
    }
    public List<ISupplier> GetSuppliers()
    {
        return suppliers;
    }
    public List<IEmployee> GetEmployees()
    {
        return employees;
    }

    public decimal GetAll()
    {
        decimal st = 0;
        foreach(var supp in suppliers)
        {
            st += supp.GetCost();
        }
        foreach (var emp in employees)
        {
            st += emp.GetSalary();
        }
        return st;
    }
}

public class Supplier : ISupplier
{
    public string Name {get;set;}
    public decimal Cost {get;set;}
    public string SupplierType {get;set;}
    public Supplier(string name, decimal cost, string supplierType)
    {
        Name = name;
        Cost = cost;
        SupplierType = supplierType;
    }

   
    public string GetName()
    {
        return Name;
    }
    public decimal GetCost()
    {
        return Cost;
    }
    public string GetSupplierType()
    {
        return SupplierType;
    }

}

public class Employee : IEmployee
{
    public string FullName { get; set; }
    public decimal Salary { get; set; }
    public string Position { get; set; }
    public Employee(string fullName, decimal salary, string position)
    {
        FullName = fullName;
        Salary = salary;
        Position = position;
    }

    public string GetFullName()
    {
        return FullName;
    }

    public decimal GetSalary()
    {
        return Salary;
    }
    public string GetPosition()
    {
        return Position;
    }

}


Supplier supplier1 = new Supplier("ООО Ромашка", 1000m, "Логистика");
Supplier supplier2 = new Supplier("Гарерава", 2000m, "Логистика");
Supplier supplier3 = new Supplier("ПООАроп", 3000m, "Поставки");

Employee employee1 = new Employee("Иванов И И ", 4000m, "Менеджер");
Employee employee2 = new Employee("Петров А в ", 5000m, "Менеджер");
Employee employee3 = new Employee("Сидоров В К", 6000m, "Приемщик");
Enterprise ep = new Enterprise();
ep.AddSupplier(supplier1);
ep.AddSupplier(supplier2);
ep.AddSupplier(supplier3);
ep.AddEmployee(employee1);
ep.AddEmployee(employee2);
ep.AddEmployee(employee3);
Console.WriteLine();
Console.WriteLine("Поставщики:");
foreach (var supplier in ep.GetSuppliers())
{
    Console.WriteLine($" {supplier.GetName()} -------- стоимость {supplier.GetCost()}");
}
Console.WriteLine();
Console.WriteLine("Сотрудники:");
foreach(var employee in ep.GetEmployees())
{
    Console.WriteLine($" {employee.GetFullName()} --------- зарплата {employee.GetSalary()}");
}
Console.WriteLine();
Console.WriteLine($"Общая сумма затрат: {ep.GetAll()}");
# Out:
# Поставщики:
#  ООО Ромашка -------- стоимость 1000
#  Гарерава -------- стоимость 2000
#  ПООАроп -------- стоимость 3000
#
# Сотрудники:
#  Иванов И И  --------- зарплата 4000
#  Петров А в  --------- зарплата 5000
#  Сидоров В К --------- зарплата 6000
#
# Общая сумма затрат: 21000
